# %% [markdown]
# # Install library

# %%
# !pip install captcha
# Out:
# Collecting captcha
#   Downloading captcha-0.7.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: Pillow in c:\users\admin\anaconda3\lib\site-packages (from captcha) (10.3.0)
# Downloading captcha-0.7.1-py3-none-any.whl (147 kB)
#    ---------------------------------------- 0.0/147.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/147.6 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/147.6 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/147.6 kB ? eta -:--:--
#    ----- --------------------------------- 20.5/147.6 kB 131.3 kB/s eta 0:00:01
#    -------- ------------------------------ 30.7/147.6 kB 146.3 kB/s eta 0:00:01
#    ---------- ---------------------------- 41.0/147.6 kB 164.3 kB/s eta 0:00:01
#    ---------- ---------------------------- 41.0/147.6 kB 164.3 kB/s eta 0:00:01
#    ------------------ -------------------- 71.7/147.6 kB 206.9 kB/s eta 0:00:01
#    -------------------------- ----------- 102.4/147.6 kB 268.7 kB/s eta 0:00:01
#    ------------------------------------ - 143.4/147.6 kB 341.3 kB/s eta 0:00:01
#    -------------------------------------- 147.6/147.6 kB 325.5 kB/s eta 0:00:00
# Installing collected packages: captcha
# Successfully installed captcha-0.7.1

# %% [markdown]
# # Import libraries

# %%
from captcha.image import ImageCaptcha
import matplotlib.pyplot as plt
import random
import string

# %% [markdown]
# # Step 1: Generate a random CAPTCHA string

# %%
def generate_captcha(length=6):
    characters = string.ascii_letters + string.digits
    return ''.join(random.choice(characters) for _ in range(length))

# %% [markdown]
# # Main logic with retry attempts

# %%
MAX_TRIES = 3
attempts = 0
success = False

while attempts < MAX_TRIES:
    captcha_text = generate_captcha()
    show_captcha(captcha_text)
    
    user_input = input("Type the CAPTCHA: ")
    
    if user_input == captcha_text:
        print("✅ Verified! You're human 😎")
        success = True
        break
    else:
        print("❌ Incorrect. Try again.\n")
        attempts += 1

if not success:
    print("🚫 Too many failed attempts. Access denied.")
# Out:
# Type the CAPTCHA:  B9xcN2
# ❌ Incorrect. Try again.
